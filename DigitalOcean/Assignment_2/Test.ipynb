# %%
import xarray as xr

file = "C:\\Users\\natal\\Downloads\\NERSC-MODEL-TOPAZ4B-ARC-RAN_mm-12km_20150715_20250428.fv2.0.nc"

ds = xr.open_dataset(file)
ds.head()
# Out:
# <xarray.Dataset> Size: 3kB
# Dimensions:        (time: 1, y: 5, x: 5, depth: 5)
# Coordinates:
#   * time           (time) datetime64[ns] 8B 2015-07-15
#   * depth          (depth) float32 20B 0.0 2.0 4.0 6.0 10.0
#     latitude       (y, x) float32 100B ...
#     longitude      (y, x) float32 100B ...
#   * x              (x) float32 20B -38.0 -37.88 -37.75 -37.62 -37.5
#   * y              (y) float32 20B -55.0 -54.88 -54.75 -54.62 -54.5
# Data variables: (12/16)
#     bottomT        (time, y, x) float32 100B ...
#     mlotst         (time, y, x) float32 100B ...
#     model_depth    (y, x) float32 100B ...
#     siconc         (time, y, x) float32 100B ...
#     sisnthick      (time, y, x) float32 100B ...
#     sithick        (time, y, x) float32 100B ...
#     ...             ...
#     vxo            (time, depth, y, x) float32 500B ...
#     vxsi           (time, y, x) float32 100B ...
#     vyo            (time, depth, y, x) float32 500B ...
# ...
